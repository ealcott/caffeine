# %%
import pandas as pd
import numpy as np
starbucks = pd.read_csv("starbucks_cleaned.csv")

# %%
starbucks.head()
# Out:
#    Unnamed: 0        Beverage_category       Beverage      Beverage_prep  \
# 0           0                   Coffee  Brewed Coffee              Short
# 1           1                   Coffee  Brewed Coffee               Tall
# 2           2                   Coffee  Brewed Coffee             Grande
# 3           3                   Coffee  Brewed Coffee              Venti
# 4           4  Classic Espresso Drinks    Caffè Latte  Short Nonfat Milk
#
#    Calories   Total Fat (g)  Trans Fat (g)   Saturated Fat (g)   Sodium (mg)  \
# 0         3             0.1             0.0                0.0             0
# 1         4             0.1             0.0                0.0             0
# 2         5             0.1             0.0                0.0             0
# 3         5             0.1             0.0                0.0             0
# 4        70             0.1             0.1                0.0             5
#
#     Total Carbohydrates (g)   ...   Dietary Fibre (g)   Sugars (g)  \
# 0                          5  ...                   0            0
# 1                         10  ...                   0            0
# 2                         10  ...                   0            0
# 3                         10  ...                   0            0
# 4                         75  ...                   0            9
#
#     Protein (g)   Vitamin A (% DV)   Vitamin C (% DV)   Calcium (% DV)   \
# 0            0.3                0.0               0.0              0.00
# 1            0.5                0.0               0.0              0.00
# 2            1.0                0.0               0.0              0.00
# 3            1.0                0.0               0.0              0.02
# 4            6.0                0.1               0.0              0.20
#
#    Iron (% DV)   Caffeine (mg)    Size         Prepped Beverages
# 0           0.0            175   Short             Brewed Coffee
# 1           0.0            260    Tall             Brewed Coffee
# 2           0.0            330  Grande             Brewed Coffee
# 3           0.0            410   Venti             Brewed Coffee
# 4           0.0             75   Short  Caffè Latte, Nonfat Milk
#
# [5 rows x 21 columns]

# %%
starbucks.drop(["Unnamed: 0", "Prepped Beverages"], axis=1, inplace=True)

# %%
##replace categorical columns with numbers
def enumerate_(column_name):
    string_name = "Enumerated_" + column_name
    starbucks[string_name] = starbucks[column_name].replace(
        starbucks[column_name].unique().tolist(), 
        np.arange(0, len(starbucks[column_name].unique()), 1).tolist()
    )

# %%
for i in ["Beverage_category", "Beverage", "Size", "Beverage_prep"]:
    enumerate_(i)
    starbucks.drop(i, axis=1, inplace=True)
starbucks.head()
# Out:
#    Calories   Total Fat (g)  Trans Fat (g)   Saturated Fat (g)   Sodium (mg)  \
# 0         3             0.1             0.0                0.0             0
# 1         4             0.1             0.0                0.0             0
# 2         5             0.1             0.0                0.0             0
# 3         5             0.1             0.0                0.0             0
# 4        70             0.1             0.1                0.0             5
#
#     Total Carbohydrates (g)   Cholesterol (mg)   Dietary Fibre (g)  \
# 0                          5                 0                   0
# 1                         10                 0                   0
# 2                         10                 0                   0
# 3                         10                 0                   0
# 4                         75                10                   0
#
#     Sugars (g)   Protein (g)   Vitamin A (% DV)   Vitamin C (% DV)  \
# 0            0            0.3                0.0               0.0
# 1            0            0.5                0.0               0.0
# 2            0            1.0                0.0               0.0
# 3            0            1.0                0.0               0.0
# 4            9            6.0                0.1               0.0
#
#     Calcium (% DV)   Iron (% DV)   Caffeine (mg)  \
# 0              0.00           0.0            175
# 1              0.00           0.0            260
# 2              0.00           0.0            330
# 3              0.02           0.0            410
# 4              0.20           0.0             75
#
#    Enumerated_Beverage_category  Enumerated_Beverage  Enumerated_Size  \
# 0                             0                    0                0
# 1                             0                    0                1
# 2                             0                    0                2
# 3                             0                    0                3
# 4                             1                    1                0
#
#    Enumerated_Beverage_prep
# 0                         0
# 1                         1
# 2                         2
# 3                         3
# 4                         4

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %%
## set X equal to all columns that aren't caffeine
X = starbucks.loc[:, :"Iron (% DV) "]
X = X.join(starbucks.loc[:, "Enumerated_Beverage_category":])

# %%
print(X)
# Out:
#      Calories   Total Fat (g)  Trans Fat (g)   Saturated Fat (g)  \
# 0           3             0.1             0.0                0.0
# 1           4             0.1             0.0                0.0
# 2           5             0.1             0.0                0.0
# 3           5             0.1             0.0                0.0
# 4          70             0.1             0.1                0.0
# ..        ...             ...             ...                ...
# 214       320             3.2             0.4                0.0
# 215       170             0.1             0.1                0.0
# 216       200             3.5             2.0                0.1
# 217       180             1.5             0.2                0.0
# 218       240             0.1             0.1                0.0
#
#       Sodium (mg)   Total Carbohydrates (g)   Cholesterol (mg)  \
# 0               0                          5                 0
# 1               0                         10                 0
# 2               0                         10                 0
# 3               0                         10                 0
# 4               5                         75                10
# ..            ...                        ...               ...
# 214             0                        250                67
# 215             0                        160                39
# 216            10                        160                39
# 217             0                        160                37
# 218             5                        230                56
#
#       Dietary Fibre (g)   Sugars (g)   Protein (g)   Vitamin A (% DV)   \
# 0                     0            0            0.3               0.00
# 1                     0            0            0.5               0.00
# 2                     0            0            1.0               0.00
# 3                     0            0            1.0               0.00
# 4                     0            9            6.0               0.10
# ..                  ...          ...            ...                ...
# 214                   1           64            5.0               0.06
# 215                   0           38            4.0               0.06
# 216                   0           38            3.0               0.06
# 217                   1           35            3.0               0.04
# 218                   0           55            5.0               0.08
#
#      Vitamin C (% DV)   Calcium (% DV)   Iron (% DV)   \
# 0                0.00              0.00          0.00
# 1                0.00              0.00          0.00
# 2                0.00              0.00          0.00
# 3                0.00              0.02          0.00
# 4                0.00              0.20          0.00
# ..                ...               ...           ...
# 214              0.08              0.20          0.10
# 215              0.00              0.10          0.00
# 216              0.00              0.10          0.00
# 217              0.00              0.10          0.06
# 218              0.00              0.15          0.00
#
#      Enumerated_Beverage_category  Enumerated_Beverage  Enumerated_Size  \
# 0                               0                    0                0
# 1                               0                    0                1
# 2                               0                    0                2
# 3                               0                    0                3
# 4                               1                    1                0
# ..                            ...                  ...              ...
# 214                             8                   28                3
# 215                             8                   29                1
# 216                             8                   29                1
# 217                             8                   29                1
# 218                             8                   29                2
#
#      Enumerated_Beverage_prep
# 0                           0
# 1                           1
# 2                           2
# 3                           3
# 4                           4
# ..                        ...
# 214                         6
# 215                         7
# 216                        12
# 217                         6
# 218                         8
#
# [219 rows x 18 columns]

# %%
## set y equal to caffeine column
y = starbucks.loc[:, "Caffeine (mg)"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
import warnings
warnings.filterwarnings('ignore')
parameters = {
    "criterion" : ["squared_error", "friedman_mse", "absolute_error", "poisson"], #default sq
    "splitter" : ["best", "random"], #default best
    "min_samples_leaf"  : [1, 2, 3, 4], #default 1
    "max_features" : ["auto", "sqrt", "log2", None] #default None
}
clf = GridSearchCV(DecisionTreeRegressor(),                    
                   param_grid = parameters,          
                   cv=5)   

clf.fit(X_train,y_train)
print("Tuned Hyperparameters :", clf.best_params_)
# Out:
# Tuned Hyperparameters : {'criterion': 'squared_error', 'max_features': 'auto', 'min_samples_leaf': 1, 'splitter': 'best'}

# %%
best_regressor = clf.best_estimator_
test_score = best_regressor.score(X_test, y_test)
print("Test R-squared score:", test_score)
# Out:
# Test R-squared score: 0.8387241903128655

# %%
criterion = clf.best_params_["criterion"]
max_feats = clf.best_params_["max_features"]
min_samples_leaf = clf.best_params_["min_samples_leaf"]
splitter = clf.best_params_["splitter"]
dtr = DecisionTreeRegressor(criterion = criterion, max_features=max_feats, min_samples_leaf = min_samples_leaf, 
                            splitter=splitter)

# %%
dtr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_features='auto')

# %%
predict = dtr.predict(X_test)

# %%
np.sqrt(metrics.mean_squared_error(y_test, predict))
# Out:
# 22.02787490266078

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")
x = np.arange(0, len(predict), 1)
plt.bar(x = x.tolist(), height = y_test, color="cornflowerblue")
plt.bar(x = x.tolist(), height = predict, color="darkred")
keys = ["Actual Value", "Predicted Value"]
plt.title("Predicted Caffeine (mg) and Actual Caffeine (mg)")
plt.ylabel("Caffeine (mg)")
plt.xlabel("Menu Item")
plt.legend(labels = keys)
plt.show()

# %%
x = np.arange(0, len(predict), 1)
plt.bar(x = x.tolist(), height = predict, color="darkred")
plt.bar(x = x.tolist(), height = y_test, color="cornflowerblue")
keys = ["Actual Value", "Predicted Value"]
plt.title("Predicted Caffeine (mg) and Actual Caffeine (mg)")
plt.ylabel("Caffeine (mg)")
plt.xlabel("Menu Item")
plt.legend(labels = keys)
plt.show()

# %%
same = []
xs = []
for i in range(len(y_test)):
    if np.array(y_test)[i] == predict[i]:
        same.append(predict[i])
        xs.append(i)

# %%
plt.bar(x = x.tolist(), height = y_test, color = "grey")
plt.bar(x = x.tolist(), height = predict, color="grey")
plt.bar(x = xs, height = same, color = "g")
keys = ["Different Value", "Matching Value"]
plt.title("Predicted Values that are the Same as the Actual Values")
plt.ylabel("Caffeine (mg)")
plt.xlabel("Menu Item")
plt.show()

# %%
dtr.feature_importances_
# Out:
# array([0.01542854, 0.00263687, 0.        , 0.        , 0.        ,
#        0.11822722, 0.03722775, 0.00064134, 0.28086283, 0.07726261,
#        0.00524023, 0.        , 0.00491776, 0.00845509, 0.01984308,
#        0.30740253, 0.11736716, 0.004487  ])

# %%
importances = dtr.feature_importances_
# [::-1] puts the sorted list in reverse order
# importances is the measured importance, features is the features
left_sorted_importances = importances[importances.argsort()[::-1]]
left_sorted_features = X_train.columns[importances.argsort()[::-1]]

plt.figure(figsize=(10, 6))
plt.bar(left_sorted_features, left_sorted_importances, color="green")
plt.xticks(rotation=90)
plt.xlabel('Nutrition Features')
plt.ylabel('Importance in Model')
plt.title('Importance of Nutrition Features in Caffeine DT Regression Model')
plt.show()
